# %% [markdown]
# # TD1 : Fondamentaux

# %%
# importation des librairies utilisées dans la suite
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Exercice 3: la légende de Sissa (boucles)

# %% [markdown]
# "En Inde, le roi Belkib (ou Bathait), qui s'ennuie à la cour, demande qu'on lui invente un jeu pour le distraire. Le sage Sissa invente alors le Chaturanga, l'ancêtre du jeu d'échecs, ce qui ravit le roi. Pour remercier Sissa, le roi lui demande de choisir sa récompense, aussi fastueuse qu'elle puisse être. Sissa choisit de demander au roi de prendre le plateau du jeu et, sur la première case, poser un grain de riz, ensuite deux sur la deuxième, puis quatre sur la troisième, et ainsi de suite, en doublant à chaque fois le nombre de grains de riz que l’on met.
#
# Le roi et la cour sont amusés par la modestie de cette demande. Le roi tente de persuader Sissa d'accepter une récompense d'une valeur plus importante. Devant le refus de Sissa, il ordonne que les grains soient apportés. Mais lorsqu'on la met en œuvre la demande, on s'aperçoit qu'il n'y a pas assez de grains de riz dans tout le royaume pour la satisfaire" (ref. [Légende de Sissa, wikipedia](https://fr.wikipedia.org/wiki/L%C3%A9gende_de_Sissa))
#
# Calculer le nombre total et la masse de grains de riz (0.05 g/unité).

# %%
# Calcul du nombre de grains de riz reçus par Sissa
# de L. Federspiel
# échiquier = 64 cases
nb_grains_sur_case_courante = 1
nb_total = 0
masse_total = 0
for i in range (64):
    nb_total += 2**i
masse_total = nb_total * 0.05

print ('Nombre total de grains de riz :', nb_total)
print ('Masse totale (en kg) :', masse_total)
# Out:
# Nombre total de grains de riz : 18446744073709551615
# Masse totale (en kg) : 9.223372036854776e+17

# %% [markdown]
# ## Exercice 4 : Division euclidienne

# %% [markdown]
# Réaliser la division euclidienne de $m$ par $n$ en affichant chaque étape, avec un critère d'arrêt IMAX de la procédure.

# %%
m = 18
n = 2
IMAX = 12
for i in range (IMAX):
    if n * (i) < m:
        q = i
        r = m - n * i
        print ('m/n = quotient :', q,'reste :', r)
    elif n * (i) == m:
        q = i
        r = 0
        print ('m/n = quotient :', q,'reste :', r)
        break
    elif n * (i) > m:
        q = i-1
        r = m - n * (i-1)
        print ('m/n = quotient :', q,'reste :', r)
        break
# Out:
# m/n = quotient : 0 reste : 18
# m/n = quotient : 1 reste : 16
# m/n = quotient : 2 reste : 14
# m/n = quotient : 3 reste : 12
# m/n = quotient : 4 reste : 10
# m/n = quotient : 5 reste : 8
# m/n = quotient : 6 reste : 6
# m/n = quotient : 7 reste : 4
# m/n = quotient : 8 reste : 2
# m/n = quotient : 9 reste : 0
