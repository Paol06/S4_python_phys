# %% [markdown]
# ## Exercice 5-$\varepsilon$ : Dictionnaires

# %% [markdown]
# Le calendrier julien, qui avait cours avant le calendrier actuel, ne distinguait pas entre elles les années de fin de siècle (années divisibles par 100). Une année était bissextile tous les quatre ans, sans exception.
# Le calendrier julien avait ainsi une durée moyenne $A_J$ en jours de :
#
# $$
# A_J = 365,25 = 365 + \frac{1}{4} ,
# $$
#
# au lieu des $A = 365,2422$ jours de l'année tropique, ce qui, au bout de quinze siècles, a engendré un décalage accumulé d'une dizaine de jours de retard dans le calendrier julien par rapport à l’année tropique.
#
# Le calendrier grégorien utilise une approximation plus fine de $A$ :
#
# $$
# A_G = 365 + \frac{1}{4} - \frac{1}{100} + \frac{1}{400} = 365.2425
# $$
#
# Cette appoximation s'applique en ajoutant un 29 février tous les 4 ans, en le retirant tous les 100 ans et en le rajoutant tous les 400 ans. Une année est ainsi bissextile si l'une des 2 conditions suivantes est vérifiée :
# - condition 1 : l'année est divisible par 4 sans être divisible par 100 (cas des années qui ne sont pas des multiples de 100) ;
# - condition 2 : l'année est divisible par 400 (cas des années multiples de 100).

# %% [markdown]
# 1. Coder en Python ces deux conditions pour une année  $x$ (sur papier).

# %% [markdown]
# 2. Inclure ces deux conditions dans une fonction qui détermine si une année $x$ est bissextile (renvoie _True_) ou non (renvoie _False_).

# %%
# définition de la fonction
def est_bissextile (x):


    
    return bissextile

# appel de la fonction dans le programme principal
x = 2026
est_bissextile (x)
# Out:
# False

# %% [markdown]
# On définit le nombre de jours dans le mois dans le dictionnaire suivant.

# %%
jours_dans_le_mois = {'janvier' : 31,
                      'février' : {False: 28, True:  29},
                      'mars' : 31,
                      'avril' : 30,
                      'mai' : 31,
                      'juin' : 30,
                      'juillet' : 31,
                      'aout' : 31,
                      'septembre' : 30,
                      'octobre' : 31,
                      'novembre' : 30}
print ('Le contenu du dictionnaire est :\n', jours_dans_le_mois)
print ('Le type de la variable est :', type (jours_dans_le_mois))
# Out:
# Le contenu du dictionnaire est :
#  {'janvier': 31, 'février': {False: 28, True: 29}, 'mars': 31, 'avril': 30, 'mai': 31, 'juin': 30, 'juillet': 31, 'aout': 31, 'septembre': 30, 'octobre': 31, 'novembre': 30}
# Le type de la variable est : <class 'dict'>

# %% [markdown]
# 3. Ecrire l'instruction qui ajoute l'entrée 'décembre' au dictionnaire.

# %%
XXX
print ('Le nouveau contenu du dictionnaire est :\n', jours_dans_le_mois)
# Out:
# Le nouveau contenu du dictionnaire est :
#  {'janvier': 31, 'février': {False: 28, True: 29}, 'mars': 31, 'avril': 30, 'mai': 31, 'juin': 30, 'juillet': 31, 'aout': 31, 'septembre': 30, 'octobre': 31, 'novembre': 30, 'décembre': 31}

# %% [markdown]
# 4. Compléter le programme suivant pour afficher le nombre de jours dans le mois de janvier.

# %%
mois = XXX
print ('Dans le mois de', mois)
print ('le nombre de jours est', XXX)
# Out:
# Dans le mois de janvier
# le nombre de jours est 31

# %% [markdown]
# 5. Compléter le programme suivant en appelant la fonction _est_bissextile()_ pour tenir compte de l'exception du mois de février.

# %%
x = 2026
mois = XXX




print ("Le nombre de jours du mois de", mois)
print ("de l'année", x)
print ('est', n)
# Out:
# Le nombre de jours du mois de février
# de l'année 2026
# est 28

# %% [markdown]
# _Rappels de cours_

# %%
print ('Les entrées du dictionnaire sont :')
print (jours_dans_le_mois.keys ())
print ('Conversion en liste :')
print (list (jours_dans_le_mois.keys ()))
# Out:
# Les entrées du dictionnaire sont :
# dict_keys(['janvier', 'février', 'mars', 'avril', 'mai', 'juin', 'juillet', 'aout', 'septembre', 'octobre', 'novembre', 'décembre'])
# Conversion en liste :
# ['janvier', 'février', 'mars', 'avril', 'mai', 'juin', 'juillet', 'aout', 'septembre', 'octobre', 'novembre', 'décembre']

# %%
print ('Les éléments du dictionnaire sont :')
jours_dans_le_mois.items ()
print ('Conversion en liste :')
list (jours_dans_le_mois.items ())
# Out:
# Les éléments du dictionnaire sont :
# Conversion en liste :
# [('janvier', 31),
#  ('février', {False: 28, True: 29}),
#  ('mars', 31),
#  ('avril', 30),
#  ('mai', 31),
#  ('juin', 30),
#  ('juillet', 31),
#  ('aout', 31),
#  ('septembre', 30),
#  ('octobre', 31),
#  ('novembre', 30),
#  ('décembre', 31)]
